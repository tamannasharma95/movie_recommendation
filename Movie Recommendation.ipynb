# %%
#Import libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import ipywidgets
from ipywidgets import interact
from ipywidgets import interact_manual

# %%
data = pd.read_csv('C:/users/Tamanna/DS stuff/day 4/movie_metadata.csv')

# %%
data.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
data.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
data.shape
# Out:
# (5043, 28)

# %%
pd.set_option('max_columns',28) #to see all columns(with ... also)
data.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# ...

# %% [markdown]
# # # No. of users who voted vs No. of users who shared reviews

# %%
plt.rcParams['figure.figsize'] = (15,4) #To set size of the figure
plt.style.use('fivethirtyeight') #To set background style of plot
sns.scatterplot(data['num_voted_users'], data['num_user_for_reviews'])

# %% [markdown]
# # # Duration vs Gross

# %%
sns.scatterplot(data['duration'], data['gross'])

# %%
sns.lineplot(data['duration'], data['gross'])

# %% [markdown]
# # # IMDB vs Gross

# %%
# since both are numeric so we pick scatter plot
sns.scatterplot(data['imdb_score'], data['gross'])

# %% [markdown]
# # # Budget vs Gross

# %%
sns.scatterplot(data['budget'], data['gross'])

# %%
# to find movies mentioned above
data[(data['budget'] > 200000000) & (data['gross'] < 200000000)][['gross','budget', 'movie_title']]
# Out:
#             gross        budget                                movie_title
# 5      73058679.0  2.637000e+08                               John Carter
# 14     89289910.0  2.150000e+08                           The Lone Ranger
# 16    141614023.0  2.250000e+08  The Chronicles of Narnia: Prince Caspian
# 19    179020854.0  2.250000e+08                            Men in Black 3
# 28     65173160.0  2.090000e+08                                Battleship
# 1016   14131298.0  3.900000e+08   The Messenger: The Story of Joan of Arc
# 1338     626809.0  5.536320e+08                                 Red Cliff
# 2323    2298191.0  2.400000e+09                         Princess Mononoke
# 2334     410388.0  2.127520e+09                                  Steamboy
# 2740     102055.0  3.000000e+08                                 Ong-bak 2
# 2988    2201412.0  1.221550e+10                                  The Host
# 3005     195888.0  2.500000e+09                                  Fateless
# ...

# %%
# to convert from rupees to dollar

def rupees_to_dollar(x):
    return x/75
   
    data['budget'] = data['budget'].apply(rupees_to_dollar)
    data['gross'] = data['gross'].apply(rupees_to_dollar)

# %%
data.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
@interact 
def plot(x = list(data.select_dtypes('object').columns),
         y = list(data.select_dtypes('number').columns)):
    return sns.barplot(data[x], data[y])
# Out:
# interactive(children=(Dropdown(description='x', options=('color', 'director_name', 'actor_2_name', 'genres', '…

# %%
@interact_manual
def plot(x = list(data.select_dtypes('object').columns),
        y = list(data.select_dtypes('number').columns)):
    sns.barplot(data[x], data[y])
    plt.xticks(rotation = 90) #to rotate the lable at 90 degree (dont forget to remove retun from function)
# Out:
# interactive(children=(Dropdown(description='x', options=('color', 'director_name', 'actor_2_name', 'genres', '…

# %% [markdown]
# # # Recommend Movies on the basis of Language

# %%
def recommend_lang(x):
    y = data[['language','movie_title','imdb_score']][data['language'] == x]
    y = y.sort_values(by = 'imdb_score', ascending = False)
    return y

# %%
recommend_lang('Hindi')
# Out:
#      language                          movie_title  imdb_score
# 3870    Hindi                             Airlift          8.5
# 3685    Hindi                     Rang De Basanti          8.4
# 4160    Hindi                Lage Raho Munna Bhai          8.2
# 3344    Hindi                     My Name Is Khan          8.0
# 3510    Hindi                          Veer-Zaara          7.9
# 1056    Hindi                               Earth          7.8
# 4385    Hindi                        The Lunchbox          7.8
# 4088    Hindi                               Water          7.8
# 4528    Hindi  Rocket Singh: Salesman of the Year          7.5
# 3789    Hindi                   Gandhi, My Father          7.4
# 4490    Hindi                     Monsoon Wedding          7.4
# 3348    Hindi                     Namastey London          7.3
# 3877    Hindi                                 Paa          7.2
# 4724    Hindi                   Faith Connections          7.0
# ...

# %%
def recommend_lang(x):   #on the basis of Language
    y = data[['language','movie_title','imdb_score']][data['language'] == x]
    y = y.sort_values(by = 'imdb_score', ascending = False)
    return y.head(5) #head if we want only 5

# %%
recommend_lang('English')
# Out:
#      language                    movie_title  imdb_score
# 2765  English  Towering Inferno                      9.5
# 1937  English      The Shawshank Redemption          9.3
# 3466  English                 The Godfather          9.2
# 2837  English        The Godfather: Part II          9.0
# 66    English               The Dark Knight          9.0

# %% [markdown]
# # #Recommendation on the basis of Actors

# %%
def actor_recommendations(x):  #acc to actors
    a = data[['movie_title','imdb_score']][data['actor_1_name'] == x]
    b = data[['movie_title','imdb_score']][data['actor_2_name'] == x]
    c = data[['movie_title','imdb_score']][data['actor_3_name'] == x]
    x = a.append(b)
    y = x.append(c)
    y = y.sort_values(by = 'imdb_score', ascending = False)
    return y

# %%
actor_recommendations('Tom Cruise')
# Out:
#                                             movie_title  imdb_score
# 1868                                          Rain Man          8.0
# 75                                    Edge of Tomorrow          7.9
# 284                                    Minority Report          7.7
# 158                                   The Last Samurai          7.7
# 736                                         Collateral          7.6
# 1524                                    A Few Good Men          7.6
# 940   Interview with the Vampire: The Vampire Chroni...         7.6
# 155               Mission: Impossible - Ghost Protocol          7.4
# 135                 Mission: Impossible - Rogue Nation          7.4
# 671                                     Eyes Wide Shut          7.3
# 930                                      Jerry Maguire          7.3
# 3128                                     The Outsiders          7.2
# 2768                        Born on the Fourth of July          7.2
# ...
